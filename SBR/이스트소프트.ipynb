# %% [markdown]
# ## Baseline model - SBR

# %% [markdown]
# ![demo](https://user-images.githubusercontent.com/97432613/160314591-413916bf-abec-4b81-b4d4-0845cc5abfb9.gif)

# %% [markdown]
# ![sbr](https://user-images.githubusercontent.com/97432613/160314242-cbea5a9c-122b-43ff-bd62-efc71897019b.png)

# %% [markdown]
# [SBR Full Paper](https://arxiv.org/pdf/1807.00966.pdf)

# %% [markdown]
# ## Stability evaluation metric

# %% [markdown]
# ![MSA_txt](https://user-images.githubusercontent.com/97432613/160314822-eb40de7e-cf42-4bd9-ad21-471dac52a0dd.png)
# ![MSA_table](https://user-images.githubusercontent.com/97432613/160314824-3c499697-49ae-456f-b2d0-28273191109c.png)

# %% [markdown]
# [Stability eval metric Full Paper](https://sci-hub.se/10.1016/j.jfranklin.2019.12.043)

# %% [markdown]
# ## Idea

# %% [markdown]
# - SRGAN 을 이용한 이미지 해상도 증가

# %% [markdown]
# ![ori-fake](https://user-images.githubusercontent.com/97432613/160349953-563460f8-8501-463d-925b-3f840fb90893.PNG)

# %%
import matplotlib.pyplot as plt
import glob
from PIL import Image 
import imageio

# %% [markdown]
# # 1. Data preprocess

# %%
# video -> image
# !python extrct_300VW.py
# !bash ./cache/Extract300VW.sh

# images -> train.lst + test.lst 
# !python generate_300VW.py

# %% [markdown]
# # 2. Train

# %% [markdown]
# [pre-trained model download](https://drive.google.com/drive/folders/1ylMoVuUaNPqP7GSeWS3yE-wfU9JEJSSu)

# %%
CUDA_VISIBLE_DEVICES=0,1 python ./exps/lk_main.py\
    --train_lists ./cache_data/lists/300VW/300VW.train.lst ./cache_data/lists/300VW/300VW.train.lst.none         \
    --eval_ilists ./cache_data/lists/300VW/300VW.test-1.lst         \
    --num_pts 68    \
    --model_config ./configs/Detector.config       \
    --opt_config   ./configs/SGD.config     \
    --lk_config    ./configs/lk.config      \
    --video_parser x-1-1    \
    --save_path ./snapshots-smalldata-3090/               \
    --init_model ./cpm_vgg16-epoch-049-050.pth     \
    --pre_crop_expand 0.2 --sigma 4 --batch_size 16 \
    --crop_perturb_max 5 --scale_prob 1 --scale_min 1 \
    --scale_max 1 --scale_eval 1 --heatmap_type gaussian --print_freq 10

# %% [markdown]
# # 3. Test - 10장 이미지로 테스트

# %% [markdown]
# #### predict

# %%
#!CUDA_VISIBLE_DEVICES=1 python ./exps/eval.py --image ./cache_data/cache/yerang.jpg --model ./cpm_vgg16-epoch-049-050.pth --face 180 100 850 1000  --save ./result/yerang-result.jpg
# !CUDA_VISIBLE_DEVICES=1 python ./exps/eval_folder.py --image_folder ./cache_data/cache/test_data --model './snapshots-smalldata/checkpoint/cpm_vgg16-epoch-033-050.pth' --face 330 30 1015 715 --save_folder './result/test_data/'
# Out:
# The image is None
# The model is ./snapshots-smalldata/checkpoint/cpm_vgg16-epoch-033-050.pth
# The face bounding box is [330.0, 30.0, 1015.0, 715.0]
# path=========================== ./configs/Detector.config
# The general dataset initialization done : GeneralDataset(point-num=-1, sigma=4.0, heatmap_type=gaussian, length=0, dataset=300W-68)
# Initialize cpm-vgg16 with configure : Configure(arch='cpm_vgg16', stages=3, dilation=[1], pooling=[True, True, True], downsample=8, argmax=4, pretrained=[True])
# vgg16_base use pre-trained model
# Prepare input data
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:4044: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:3982: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (460.8, 315.8), score = 0.41
# the 01/68-th point : (453.6, 363.0), score = 0.80
# the 02/68-th point : (457.3, 425.1), score = 0.67
# the 03/68-th point : (470.1, 488.2), score = 0.34
# the 04/68-th point : (482.2, 557.3), score = 0.40
# the 05/68-th point : (508.0, 621.8), score = 0.42
# the 06/68-th point : (548.0, 660.7), score = 0.25
# the 07/68-th point : (613.2, 692.0), score = 0.12
# the 08/68-th point : (646.6, 678.1), score = 0.00
# the 09/68-th point : (712.4, 691.6), score = 0.06
# the 10/68-th point : (776.3, 677.4), score = 0.40
# the 11/68-th point : (812.5, 626.9), score = 0.46
# the 12/68-th point : (840.1, 572.2), score = 0.48
# the 13/68-th point : (857.8, 509.1), score = 0.58
# the 14/68-th point : (873.1, 451.9), score = 0.52
# the 15/68-th point : (881.1, 393.9), score = 0.80
# the 16/68-th point : (888.4, 340.3), score = 0.78
# the 17/68-th point : (486.3, 277.3), score = 0.71
# the 18/68-th point : (512.6, 258.1), score = 0.82
# the 19/68-th point : (554.9, 255.0), score = 0.59
# the 20/68-th point : (599.5, 265.9), score = 0.75
# the 21/68-th point : (638.6, 280.6), score = 0.57
# the 22/68-th point : (726.5, 286.9), score = 0.51
# the 23/68-th point : (762.8, 271.2), score = 0.48
# the 24/68-th point : (813.4, 271.0), score = 0.41
# the 25/68-th point : (854.1, 285.5), score = 0.74
# the 26/68-th point : (866.5, 310.0), score = 0.41
# the 27/68-th point : (682.6, 312.1), score = 0.68
# the 28/68-th point : (685.4, 348.3), score = 0.92
# the 29/68-th point : (683.8, 382.7), score = 0.73
# the 30/68-th point : (685.2, 422.4), score = 0.59
# the 31/68-th point : (624.2, 462.5), score = 0.70
# the 32/68-th point : (652.4, 472.2), score = 0.63
# the 33/68-th point : (679.6, 477.6), score = 0.79
# the 34/68-th point : (706.2, 471.8), score = 0.66
# the 35/68-th point : (730.4, 464.9), score = 0.47
# the 36/68-th point : (528.0, 305.2), score = 0.63
# the 37/68-th point : (554.0, 297.3), score = 0.51
# the 38/68-th point : (585.9, 296.4), score = 0.52
# the 39/68-th point : (614.0, 308.1), score = 0.54
# the 40/68-th point : (585.6, 309.4), score = 0.53
# the 41/68-th point : (556.9, 308.6), score = 0.47
# the 42/68-th point : (730.6, 318.6), score = 0.63
# the 43/68-th point : (767.1, 310.3), score = 0.74
# the 44/68-th point : (797.7, 314.7), score = 0.59
# the 45/68-th point : (825.7, 325.4), score = 0.86
# the 46/68-th point : (799.8, 325.3), score = 0.86
# the 47/68-th point : (763.9, 321.7), score = 0.81
# the 48/68-th point : (600.9, 566.7), score = 0.78
# the 49/68-th point : (627.6, 542.5), score = 0.87
# the 50/68-th point : (658.6, 530.2), score = 0.65
# the 51/68-th point : (680.1, 535.8), score = 0.60
# the 52/68-th point : (702.0, 532.5), score = 0.49
# the 53/68-th point : (732.7, 543.7), score = 0.78
# the 54/68-th point : (755.5, 569.3), score = 0.44
# the 55/68-th point : (729.0, 596.4), score = 0.47
# the 56/68-th point : (700.8, 611.4), score = 0.56
# the 57/68-th point : (675.1, 611.8), score = 0.61
# the 58/68-th point : (652.5, 608.1), score = 0.78
# the 59/68-th point : (624.9, 593.7), score = 0.65
# the 60/68-th point : (617.0, 565.8), score = 0.58
# the 61/68-th point : (657.4, 552.7), score = 0.60
# the 62/68-th point : (678.7, 553.8), score = 0.55
# the 63/68-th point : (701.7, 553.7), score = 0.50
# the 64/68-th point : (736.9, 568.3), score = 0.66
# the 65/68-th point : (699.6, 573.9), score = 0.39
# the 66/68-th point : (679.4, 574.6), score = 0.52
# the 67/68-th point : (655.3, 571.0), score = 0.66
# save the visualization results into None
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (459.5, 301.1), score = 0.49
# the 01/68-th point : (454.8, 347.1), score = 0.74
# the 02/68-th point : (453.3, 410.0), score = 0.84
# the 03/68-th point : (464.5, 472.3), score = 0.56
# the 04/68-th point : (476.9, 542.3), score = 0.59
# the 05/68-th point : (508.2, 603.9), score = 0.65
# the 06/68-th point : (549.4, 652.4), score = 0.49
# the 07/68-th point : (607.5, 688.7), score = 0.57
# the 08/68-th point : (671.1, 691.8), score = 0.31
# the 09/68-th point : (722.1, 687.7), score = 0.41
# the 10/68-th point : (777.7, 653.0), score = 0.64
# the 11/68-th point : (813.9, 602.7), score = 0.55
# the 12/68-th point : (841.3, 549.5), score = 0.52
# the 13/68-th point : (856.4, 490.6), score = 0.71
# the 14/68-th point : (869.1, 434.5), score = 0.65
# the 15/68-th point : (876.7, 378.7), score = 0.49
# the 16/68-th point : (876.8, 323.9), score = 0.80
# the 17/68-th point : (488.3, 268.8), score = 0.62
# the 18/68-th point : (511.0, 246.4), score = 0.61
# the 19/68-th point : (552.7, 243.3), score = 0.65
# the 20/68-th point : (593.2, 250.0), score = 0.47
# the 21/68-th point : (635.6, 265.6), score = 0.56
# the 22/68-th point : (719.1, 268.9), score = 0.52
# the 23/68-th point : (755.1, 253.4), score = 0.51
# the 24/68-th point : (801.9, 252.1), score = 0.64
# the 25/68-th point : (841.4, 265.0), score = 0.49
# the 26/68-th point : (854.6, 290.8), score = 0.42
# the 27/68-th point : (674.1, 294.6), score = 0.49
# the 28/68-th point : (677.0, 328.4), score = 0.69
# the 29/68-th point : (676.5, 358.6), score = 0.53
# the 30/68-th point : (678.7, 393.9), score = 0.71
# the 31/68-th point : (619.9, 436.4), score = 0.72
# the 32/68-th point : (646.4, 445.4), score = 0.44
# the 33/68-th point : (672.8, 449.6), score = 0.53
# the 34/68-th point : (698.8, 445.5), score = 0.35
# the 35/68-th point : (724.3, 439.4), score = 0.58
# the 36/68-th point : (526.1, 294.9), score = 0.52
# the 37/68-th point : (549.3, 286.7), score = 0.60
# the 38/68-th point : (581.2, 283.7), score = 0.56
# the 39/68-th point : (611.9, 291.9), score = 0.39
# the 40/68-th point : (582.8, 295.3), score = 0.54
# the 41/68-th point : (552.9, 297.3), score = 0.59
# the 42/68-th point : (728.4, 301.8), score = 0.60
# the 43/68-th point : (759.7, 297.7), score = 0.57
# the 44/68-th point : (792.5, 302.6), score = 0.74
# the 45/68-th point : (820.9, 310.8), score = 0.62
# the 46/68-th point : (791.7, 313.8), score = 0.51
# the 47/68-th point : (757.3, 307.8), score = 0.57
# the 48/68-th point : (594.7, 538.0), score = 0.67
# the 49/68-th point : (619.1, 511.9), score = 0.47
# the 50/68-th point : (653.8, 498.5), score = 0.84
# the 51/68-th point : (674.5, 504.2), score = 0.67
# the 52/68-th point : (696.9, 500.1), score = 0.55
# the 53/68-th point : (731.5, 513.3), score = 0.56
# the 54/68-th point : (750.2, 541.9), score = 0.66
# the 55/68-th point : (729.6, 576.4), score = 0.52
# the 56/68-th point : (700.5, 593.7), score = 0.50
# the 57/68-th point : (673.1, 595.8), score = 0.48
# the 58/68-th point : (647.6, 591.4), score = 0.69
# the 59/68-th point : (615.5, 574.0), score = 0.49
# the 60/68-th point : (612.5, 538.1), score = 0.57
# the 61/68-th point : (652.6, 520.2), score = 0.88
# the 62/68-th point : (675.7, 521.9), score = 0.74
# the 63/68-th point : (698.8, 523.5), score = 0.55
# the 64/68-th point : (734.2, 541.0), score = 0.69
# the 65/68-th point : (697.2, 554.4), score = 0.45
# the 66/68-th point : (674.6, 555.9), score = 0.55
# the 67/68-th point : (650.9, 552.1), score = 0.53
# save the visualization results into None
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (464.1, 295.9), score = 0.44
# the 01/68-th point : (455.9, 345.6), score = 0.80
# the 02/68-th point : (452.3, 406.5), score = 0.74
# the 03/68-th point : (461.1, 468.7), score = 0.49
# the 04/68-th point : (469.2, 539.5), score = 0.39
# the 05/68-th point : (497.9, 602.9), score = 0.45
# the 06/68-th point : (541.9, 651.6), score = 0.54
# the 07/68-th point : (600.9, 688.8), score = 0.62
# the 08/68-th point : (666.8, 691.6), score = 0.36
# the 09/68-th point : (722.3, 688.2), score = 0.48
# the 10/68-th point : (774.3, 655.5), score = 0.62
# the 11/68-th point : (811.8, 604.9), score = 0.63
# the 12/68-th point : (840.0, 551.1), score = 0.51
# the 13/68-th point : (855.7, 491.1), score = 0.74
# the 14/68-th point : (868.1, 435.0), score = 0.69
# the 15/68-th point : (875.0, 379.7), score = 0.43
# the 16/68-th point : (877.5, 325.3), score = 0.81
# the 17/68-th point : (487.6, 272.4), score = 0.57
# the 18/68-th point : (513.1, 248.7), score = 0.49
# the 19/68-th point : (553.0, 246.1), score = 0.57
# the 20/68-th point : (592.7, 253.7), score = 0.56
# the 21/68-th point : (629.3, 270.6), score = 0.51
# the 22/68-th point : (722.6, 275.8), score = 0.40
# the 23/68-th point : (757.9, 259.0), score = 0.58
# the 24/68-th point : (800.4, 258.6), score = 0.81
# the 25/68-th point : (840.7, 268.8), score = 0.45
# the 26/68-th point : (852.3, 288.7), score = 0.41
# the 27/68-th point : (675.9, 299.9), score = 0.67
# the 28/68-th point : (677.2, 333.5), score = 0.55
# the 29/68-th point : (676.3, 364.6), score = 0.71
# the 30/68-th point : (677.3, 401.1), score = 0.48
# the 31/68-th point : (618.6, 440.9), score = 0.57
# the 32/68-th point : (644.9, 450.2), score = 0.48
# the 33/68-th point : (671.6, 455.5), score = 0.59
# the 34/68-th point : (698.1, 450.7), score = 0.46
# the 35/68-th point : (723.0, 444.5), score = 0.46
# the 36/68-th point : (529.3, 301.2), score = 0.52
# the 37/68-th point : (552.4, 296.7), score = 0.51
# the 38/68-th point : (581.1, 295.8), score = 0.46
# the 39/68-th point : (611.6, 297.3), score = 0.45
# the 40/68-th point : (583.5, 302.4), score = 0.53
# the 41/68-th point : (555.4, 302.8), score = 0.50
# the 42/68-th point : (726.5, 309.7), score = 0.47
# the 43/68-th point : (763.3, 311.3), score = 0.48
# the 44/68-th point : (794.4, 315.7), score = 0.45
# the 45/68-th point : (816.1, 316.5), score = 0.51
# the 46/68-th point : (794.6, 321.9), score = 0.64
# the 47/68-th point : (759.7, 317.7), score = 0.51
# the 48/68-th point : (590.8, 540.4), score = 0.63
# the 49/68-th point : (617.5, 514.1), score = 0.54
# the 50/68-th point : (653.0, 501.7), score = 0.82
# the 51/68-th point : (672.8, 508.3), score = 0.53
# the 52/68-th point : (698.9, 504.1), score = 0.54
# the 53/68-th point : (729.4, 517.0), score = 0.63
# the 54/68-th point : (749.4, 543.1), score = 0.68
# the 55/68-th point : (726.9, 574.4), score = 0.40
# the 56/68-th point : (696.8, 589.9), score = 0.50
# the 57/68-th point : (671.0, 592.4), score = 0.53
# the 58/68-th point : (645.3, 587.9), score = 0.71
# the 59/68-th point : (614.0, 573.1), score = 0.47
# the 60/68-th point : (609.3, 540.0), score = 0.71
# the 61/68-th point : (650.8, 523.4), score = 0.82
# the 62/68-th point : (673.2, 525.9), score = 0.65
# the 63/68-th point : (700.9, 526.3), score = 0.55
# the 64/68-th point : (732.5, 542.7), score = 0.67
# the 65/68-th point : (698.6, 552.5), score = 0.38
# the 66/68-th point : (672.1, 554.1), score = 0.47
# the 67/68-th point : (649.4, 553.5), score = 0.54
# save the visualization results into None
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (464.0, 296.2), score = 0.39
# the 01/68-th point : (457.2, 343.9), score = 0.81
# the 02/68-th point : (455.0, 406.1), score = 0.73
# the 03/68-th point : (464.4, 467.5), score = 0.43
# the 04/68-th point : (474.1, 538.8), score = 0.47
# the 05/68-th point : (502.8, 601.5), score = 0.50
# the 06/68-th point : (545.5, 650.5), score = 0.55
# the 07/68-th point : (603.6, 688.0), score = 0.62
# the 08/68-th point : (669.2, 691.4), score = 0.37
# the 09/68-th point : (725.3, 687.2), score = 0.43
# the 10/68-th point : (776.3, 652.4), score = 0.68
# the 11/68-th point : (813.2, 602.2), score = 0.57
# the 12/68-th point : (841.5, 548.1), score = 0.55
# the 13/68-th point : (857.3, 488.9), score = 0.66
# the 14/68-th point : (870.7, 433.4), score = 0.64
# the 15/68-th point : (877.8, 377.7), score = 0.54
# the 16/68-th point : (879.2, 323.3), score = 0.87
# the 17/68-th point : (489.4, 269.1), score = 0.62
# the 18/68-th point : (512.8, 246.2), score = 0.62
# the 19/68-th point : (554.4, 243.9), score = 0.59
# the 20/68-th point : (593.9, 250.2), score = 0.46
# the 21/68-th point : (632.8, 267.0), score = 0.57
# the 22/68-th point : (724.2, 273.7), score = 0.33
# the 23/68-th point : (759.3, 256.1), score = 0.49
# the 24/68-th point : (802.1, 255.0), score = 0.71
# the 25/68-th point : (841.7, 266.1), score = 0.50
# the 26/68-th point : (855.0, 287.9), score = 0.52
# the 27/68-th point : (676.7, 295.9), score = 0.59
# the 28/68-th point : (679.0, 330.6), score = 0.70
# the 29/68-th point : (677.8, 361.1), score = 0.62
# the 30/68-th point : (679.4, 396.4), score = 0.68
# the 31/68-th point : (620.3, 437.4), score = 0.70
# the 32/68-th point : (647.0, 446.6), score = 0.41
# the 33/68-th point : (673.3, 451.5), score = 0.57
# the 34/68-th point : (699.1, 446.8), score = 0.39
# the 35/68-th point : (724.3, 440.6), score = 0.55
# the 36/68-th point : (528.6, 298.2), score = 0.51
# the 37/68-th point : (553.0, 292.0), score = 0.42
# the 38/68-th point : (582.9, 289.4), score = 0.35
# the 39/68-th point : (613.8, 293.7), score = 0.36
# the 40/68-th point : (585.3, 298.7), score = 0.49
# the 41/68-th point : (556.7, 299.6), score = 0.50
# the 42/68-th point : (727.5, 304.5), score = 0.60
# the 43/68-th point : (762.1, 305.0), score = 0.61
# the 44/68-th point : (793.8, 309.9), score = 0.65
# the 45/68-th point : (817.9, 314.7), score = 0.48
# the 46/68-th point : (794.0, 316.8), score = 0.58
# the 47/68-th point : (759.5, 313.6), score = 0.42
# the 48/68-th point : (594.4, 537.0), score = 0.65
# the 49/68-th point : (620.3, 511.3), score = 0.47
# the 50/68-th point : (654.0, 499.0), score = 0.85
# the 51/68-th point : (674.6, 505.0), score = 0.65
# the 52/68-th point : (697.1, 501.1), score = 0.55
# the 53/68-th point : (731.6, 513.9), score = 0.57
# the 54/68-th point : (750.3, 540.7), score = 0.65
# the 55/68-th point : (729.2, 573.7), score = 0.47
# the 56/68-th point : (699.5, 588.0), score = 0.60
# the 57/68-th point : (673.1, 590.2), score = 0.62
# the 58/68-th point : (647.2, 586.5), score = 0.75
# the 59/68-th point : (616.1, 570.7), score = 0.57
# the 60/68-th point : (612.4, 537.0), score = 0.56
# the 61/68-th point : (652.7, 520.6), score = 0.89
# the 62/68-th point : (675.7, 522.7), score = 0.73
# the 63/68-th point : (699.0, 523.7), score = 0.56
# the 64/68-th point : (734.0, 539.6), score = 0.68
# the 65/68-th point : (701.0, 553.1), score = 0.36
# the 66/68-th point : (674.7, 551.5), score = 0.45
# the 67/68-th point : (650.8, 551.6), score = 0.61
# save the visualization results into None
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (465.1, 303.9), score = 0.53
# the 01/68-th point : (455.1, 351.7), score = 0.63
# the 02/68-th point : (453.6, 411.5), score = 0.83
# the 03/68-th point : (463.8, 472.0), score = 0.47
# the 04/68-th point : (467.8, 543.5), score = 0.37
# the 05/68-th point : (497.4, 605.6), score = 0.47
# the 06/68-th point : (540.2, 654.2), score = 0.49
# the 07/68-th point : (603.9, 689.3), score = 0.54
# the 08/68-th point : (668.8, 691.8), score = 0.27
# the 09/68-th point : (723.7, 689.2), score = 0.44
# the 10/68-th point : (774.9, 660.6), score = 0.46
# the 11/68-th point : (813.9, 610.9), score = 0.48
# the 12/68-th point : (842.7, 556.2), score = 0.45
# the 13/68-th point : (858.6, 498.5), score = 0.87
# the 14/68-th point : (871.4, 442.6), score = 0.46
# the 15/68-th point : (877.7, 383.3), score = 0.71
# the 16/68-th point : (880.9, 331.0), score = 0.69
# the 17/68-th point : (486.9, 272.3), score = 0.53
# the 18/68-th point : (512.7, 250.1), score = 0.54
# the 19/68-th point : (552.8, 247.8), score = 0.51
# the 20/68-th point : (594.0, 257.2), score = 0.70
# the 21/68-th point : (630.7, 272.9), score = 0.49
# the 22/68-th point : (726.6, 279.4), score = 0.42
# the 23/68-th point : (758.2, 262.7), score = 0.56
# the 24/68-th point : (805.9, 262.0), score = 0.76
# the 25/68-th point : (844.8, 272.7), score = 0.38
# the 26/68-th point : (857.3, 297.8), score = 0.60
# the 27/68-th point : (678.6, 303.2), score = 0.76
# the 28/68-th point : (679.1, 337.1), score = 0.56
# the 29/68-th point : (677.7, 369.7), score = 0.75
# the 30/68-th point : (678.5, 407.3), score = 0.63
# the 31/68-th point : (621.5, 446.6), score = 0.55
# the 32/68-th point : (646.9, 456.2), score = 0.66
# the 33/68-th point : (673.7, 461.9), score = 0.59
# the 34/68-th point : (700.0, 457.0), score = 0.60
# the 35/68-th point : (726.3, 449.8), score = 0.48
# the 36/68-th point : (525.4, 303.4), score = 0.66
# the 37/68-th point : (550.4, 298.8), score = 0.62
# the 38/68-th point : (582.6, 299.2), score = 0.53
# the 39/68-th point : (613.9, 301.5), score = 0.48
# the 40/68-th point : (584.4, 306.2), score = 0.54
# the 41/68-th point : (553.3, 305.9), score = 0.57
# the 42/68-th point : (730.9, 311.7), score = 0.51
# the 43/68-th point : (766.8, 311.1), score = 0.58
# the 44/68-th point : (796.7, 315.8), score = 0.51
# the 45/68-th point : (820.9, 319.0), score = 0.67
# the 46/68-th point : (797.7, 323.6), score = 0.74
# the 47/68-th point : (762.3, 317.8), score = 0.61
# the 48/68-th point : (594.3, 546.2), score = 0.73
# the 49/68-th point : (623.0, 521.6), score = 0.81
# the 50/68-th point : (654.4, 510.3), score = 0.60
# the 51/68-th point : (675.9, 515.7), score = 0.61
# the 52/68-th point : (697.8, 511.7), score = 0.39
# the 53/68-th point : (731.3, 523.3), score = 0.74
# the 54/68-th point : (752.3, 548.6), score = 0.50
# the 55/68-th point : (727.7, 578.8), score = 0.54
# the 56/68-th point : (699.6, 593.6), score = 0.48
# the 57/68-th point : (673.5, 595.1), score = 0.50
# the 58/68-th point : (649.1, 590.6), score = 0.73
# the 59/68-th point : (618.4, 575.9), score = 0.48
# the 60/68-th point : (613.4, 545.4), score = 0.64
# the 61/68-th point : (653.1, 532.6), score = 0.56
# the 62/68-th point : (675.2, 531.6), score = 0.48
# the 63/68-th point : (698.5, 534.3), score = 0.36
# the 64/68-th point : (735.7, 548.7), score = 0.61
# the 65/68-th point : (697.1, 556.0), score = 0.47
# the 66/68-th point : (675.7, 557.1), score = 0.60
# the 67/68-th point : (653.1, 553.7), score = 0.56
# save the visualization results into None
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (462.9, 308.3), score = 0.53
# the 01/68-th point : (453.7, 355.4), score = 0.52
# the 02/68-th point : (454.5, 414.4), score = 0.83
# the 03/68-th point : (464.9, 475.3), score = 0.51
# the 04/68-th point : (469.7, 546.5), score = 0.42
# the 05/68-th point : (494.5, 606.7), score = 0.48
# the 06/68-th point : (537.8, 655.0), score = 0.45
# the 07/68-th point : (603.5, 689.7), score = 0.55
# the 08/68-th point : (668.7, 692.0), score = 0.26
# the 09/68-th point : (724.4, 689.6), score = 0.42
# the 10/68-th point : (775.6, 659.8), score = 0.48
# the 11/68-th point : (814.1, 613.0), score = 0.44
# the 12/68-th point : (840.8, 557.1), score = 0.48
# the 13/68-th point : (858.6, 498.8), score = 0.86
# the 14/68-th point : (872.2, 442.9), score = 0.44
# the 15/68-th point : (880.0, 383.0), score = 0.76
# the 16/68-th point : (883.7, 330.8), score = 0.76
# the 17/68-th point : (486.5, 272.6), score = 0.53
# the 18/68-th point : (511.9, 249.2), score = 0.53
# the 19/68-th point : (552.2, 248.8), score = 0.50
# the 20/68-th point : (594.8, 258.0), score = 0.75
# the 21/68-th point : (633.7, 273.5), score = 0.48
# the 22/68-th point : (723.1, 278.3), score = 0.49
# the 23/68-th point : (757.6, 262.8), score = 0.56
# the 24/68-th point : (807.8, 261.6), score = 0.71
# the 25/68-th point : (848.5, 272.9), score = 0.45
# the 26/68-th point : (860.1, 297.1), score = 0.52
# the 27/68-th point : (677.3, 303.1), score = 0.73
# the 28/68-th point : (679.2, 338.6), score = 0.62
# the 29/68-th point : (678.4, 372.2), score = 0.72
# the 30/68-th point : (680.1, 410.7), score = 0.75
# the 31/68-th point : (622.4, 450.8), score = 0.71
# the 32/68-th point : (647.9, 460.1), score = 0.67
# the 33/68-th point : (674.6, 465.5), score = 0.53
# the 34/68-th point : (701.6, 459.7), score = 0.62
# the 35/68-th point : (727.7, 452.9), score = 0.51
# the 36/68-th point : (526.2, 301.6), score = 0.65
# the 37/68-th point : (550.2, 293.3), score = 0.51
# the 38/68-th point : (584.4, 292.3), score = 0.40
# the 39/68-th point : (613.7, 301.0), score = 0.47
# the 40/68-th point : (584.7, 303.7), score = 0.57
# the 41/68-th point : (554.2, 303.8), score = 0.61
# the 42/68-th point : (727.1, 310.2), score = 0.53
# the 43/68-th point : (763.0, 303.3), score = 0.69
# the 44/68-th point : (795.8, 309.5), score = 0.74
# the 45/68-th point : (824.1, 316.2), score = 0.69
# the 46/68-th point : (795.4, 319.1), score = 0.71
# the 47/68-th point : (759.7, 314.6), score = 0.48
# the 48/68-th point : (595.1, 552.5), score = 0.58
# the 49/68-th point : (624.0, 528.8), score = 0.71
# the 50/68-th point : (655.3, 516.4), score = 0.76
# the 51/68-th point : (675.7, 522.9), score = 0.75
# the 52/68-th point : (698.6, 518.0), score = 0.53
# the 53/68-th point : (731.4, 530.5), score = 0.58
# the 54/68-th point : (753.8, 551.8), score = 0.41
# the 55/68-th point : (727.1, 579.3), score = 0.54
# the 56/68-th point : (700.1, 590.9), score = 0.53
# the 57/68-th point : (673.7, 592.8), score = 0.57
# the 58/68-th point : (649.7, 588.6), score = 0.77
# the 59/68-th point : (619.5, 574.9), score = 0.51
# the 60/68-th point : (614.3, 550.8), score = 0.50
# the 61/68-th point : (655.1, 538.3), score = 0.79
# the 62/68-th point : (676.6, 539.3), score = 0.72
# the 63/68-th point : (698.6, 538.8), score = 0.53
# the 64/68-th point : (735.3, 551.5), score = 0.50
# the 65/68-th point : (697.4, 555.1), score = 0.46
# the 66/68-th point : (676.2, 556.0), score = 0.58
# the 67/68-th point : (653.7, 553.1), score = 0.54
# save the visualization results into None
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (459.9, 309.1), score = 0.52
# the 01/68-th point : (453.4, 353.5), score = 0.51
# the 02/68-th point : (456.5, 415.0), score = 0.82
# the 03/68-th point : (467.8, 476.2), score = 0.48
# the 04/68-th point : (472.8, 547.9), score = 0.46
# the 05/68-th point : (495.5, 607.5), score = 0.44
# the 06/68-th point : (537.5, 655.7), score = 0.38
# the 07/68-th point : (603.3, 690.2), score = 0.49
# the 08/68-th point : (666.8, 692.3), score = 0.22
# the 09/68-th point : (722.7, 690.3), score = 0.40
# the 10/68-th point : (775.4, 662.3), score = 0.52
# the 11/68-th point : (814.0, 614.2), score = 0.42
# the 12/68-th point : (841.0, 557.3), score = 0.47
# the 13/68-th point : (858.6, 498.4), score = 0.85
# the 14/68-th point : (870.2, 441.8), score = 0.44
# the 15/68-th point : (881.3, 382.0), score = 0.76
# the 16/68-th point : (885.3, 330.0), score = 0.84
# the 17/68-th point : (485.6, 271.0), score = 0.53
# the 18/68-th point : (509.4, 248.8), score = 0.51
# the 19/68-th point : (550.2, 249.3), score = 0.57
# the 20/68-th point : (592.8, 257.0), score = 0.71
# the 21/68-th point : (633.8, 271.5), score = 0.45
# the 22/68-th point : (719.8, 275.0), score = 0.44
# the 23/68-th point : (757.3, 259.6), score = 0.55
# the 24/68-th point : (806.5, 257.8), score = 0.74
# the 25/68-th point : (848.3, 270.8), score = 0.48
# the 26/68-th point : (860.3, 292.5), score = 0.44
# the 27/68-th point : (676.8, 301.2), score = 0.70
# the 28/68-th point : (678.9, 337.5), score = 0.58
# the 29/68-th point : (678.3, 371.9), score = 0.73
# the 30/68-th point : (680.0, 411.0), score = 0.76
# the 31/68-th point : (621.9, 451.7), score = 0.72
# the 32/68-th point : (647.4, 461.1), score = 0.63
# the 33/68-th point : (674.4, 466.6), score = 0.48
# the 34/68-th point : (701.5, 460.8), score = 0.59
# the 35/68-th point : (728.1, 454.2), score = 0.51
# the 36/68-th point : (525.0, 298.8), score = 0.67
# the 37/68-th point : (549.6, 290.7), score = 0.51
# the 38/68-th point : (584.1, 289.2), score = 0.45
# the 39/68-th point : (613.6, 298.4), score = 0.45
# the 40/68-th point : (584.7, 300.9), score = 0.58
# the 41/68-th point : (553.1, 302.5), score = 0.66
# the 42/68-th point : (726.3, 307.8), score = 0.55
# the 43/68-th point : (760.8, 298.1), score = 0.62
# the 44/68-th point : (793.9, 303.3), score = 0.76
# the 45/68-th point : (821.8, 314.0), score = 0.61
# the 46/68-th point : (793.3, 316.0), score = 0.62
# the 47/68-th point : (758.4, 313.8), score = 0.44
# the 48/68-th point : (594.6, 553.1), score = 0.50
# the 49/68-th point : (623.4, 532.5), score = 0.56
# the 50/68-th point : (655.2, 519.9), score = 0.83
# the 51/68-th point : (675.0, 525.6), score = 0.70
# the 52/68-th point : (698.1, 521.4), score = 0.56
# the 53/68-th point : (730.5, 532.2), score = 0.47
# the 54/68-th point : (754.4, 555.8), score = 0.48
# the 55/68-th point : (727.2, 582.9), score = 0.59
# the 56/68-th point : (699.1, 594.3), score = 0.43
# the 57/68-th point : (672.8, 595.9), score = 0.44
# the 58/68-th point : (648.4, 592.5), score = 0.65
# the 59/68-th point : (618.2, 578.6), score = 0.58
# the 60/68-th point : (614.1, 554.4), score = 0.42
# the 61/68-th point : (654.1, 541.1), score = 0.83
# the 62/68-th point : (676.3, 542.0), score = 0.72
# the 63/68-th point : (698.2, 542.6), score = 0.55
# the 64/68-th point : (735.5, 555.0), score = 0.62
# the 65/68-th point : (697.0, 558.9), score = 0.51
# the 66/68-th point : (675.5, 559.8), score = 0.65
# the 67/68-th point : (653.0, 556.8), score = 0.67
# save the visualization results into None
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (458.2, 308.6), score = 0.53
# the 01/68-th point : (452.4, 353.9), score = 0.52
# the 02/68-th point : (456.3, 416.1), score = 0.81
# the 03/68-th point : (468.3, 477.7), score = 0.49
# the 04/68-th point : (475.9, 549.7), score = 0.48
# the 05/68-th point : (495.9, 609.4), score = 0.40
# the 06/68-th point : (537.7, 657.3), score = 0.34
# the 07/68-th point : (604.4, 690.6), score = 0.42
# the 08/68-th point : (664.6, 692.2), score = 0.18
# the 09/68-th point : (721.5, 690.8), score = 0.33
# the 10/68-th point : (775.1, 665.4), score = 0.55
# the 11/68-th point : (814.1, 616.9), score = 0.36
# the 12/68-th point : (842.7, 559.6), score = 0.51
# the 13/68-th point : (858.2, 499.7), score = 0.81
# the 14/68-th point : (872.5, 443.2), score = 0.42
# the 15/68-th point : (881.1, 382.1), score = 0.75
# the 16/68-th point : (885.4, 329.8), score = 0.85
# the 17/68-th point : (484.5, 270.8), score = 0.51
# the 18/68-th point : (508.6, 249.7), score = 0.54
# the 19/68-th point : (549.3, 249.8), score = 0.57
# the 20/68-th point : (592.4, 257.3), score = 0.71
# the 21/68-th point : (634.2, 271.8), score = 0.45
# the 22/68-th point : (721.1, 275.2), score = 0.43
# the 23/68-th point : (758.3, 259.6), score = 0.57
# the 24/68-th point : (807.6, 257.5), score = 0.72
# the 25/68-th point : (848.7, 269.9), score = 0.52
# the 26/68-th point : (861.0, 292.0), score = 0.44
# the 27/68-th point : (677.4, 301.5), score = 0.72
# the 28/68-th point : (679.4, 338.5), score = 0.62
# the 29/68-th point : (679.1, 373.4), score = 0.70
# the 30/68-th point : (680.6, 412.6), score = 0.79
# the 31/68-th point : (622.2, 453.6), score = 0.76
# the 32/68-th point : (648.2, 463.0), score = 0.60
# the 33/68-th point : (675.3, 467.8), score = 0.45
# the 34/68-th point : (702.3, 462.5), score = 0.57
# the 35/68-th point : (725.9, 455.6), score = 0.52
# the 36/68-th point : (525.3, 298.2), score = 0.65
# the 37/68-th point : (550.0, 289.7), score = 0.55
# the 38/68-th point : (584.5, 288.6), score = 0.45
# the 39/68-th point : (614.0, 298.5), score = 0.44
# the 40/68-th point : (585.1, 300.8), score = 0.56
# the 41/68-th point : (553.3, 302.2), score = 0.66
# the 42/68-th point : (726.3, 307.6), score = 0.55
# the 43/68-th point : (760.7, 297.4), score = 0.60
# the 44/68-th point : (793.8, 302.5), score = 0.76
# the 45/68-th point : (821.7, 313.6), score = 0.59
# the 46/68-th point : (793.4, 315.6), score = 0.61
# the 47/68-th point : (758.4, 313.5), score = 0.45
# the 48/68-th point : (596.0, 556.0), score = 0.60
# the 49/68-th point : (624.1, 533.5), score = 0.53
# the 50/68-th point : (656.0, 522.0), score = 0.84
# the 51/68-th point : (675.8, 527.6), score = 0.64
# the 52/68-th point : (698.6, 523.4), score = 0.57
# the 53/68-th point : (730.7, 535.0), score = 0.54
# the 54/68-th point : (754.9, 558.8), score = 0.53
# the 55/68-th point : (727.9, 584.6), score = 0.61
# the 56/68-th point : (699.7, 596.1), score = 0.37
# the 57/68-th point : (673.7, 595.3), score = 0.44
# the 58/68-th point : (648.8, 594.7), score = 0.59
# the 59/68-th point : (619.5, 581.0), score = 0.65
# the 60/68-th point : (615.5, 555.7), score = 0.40
# the 61/68-th point : (654.4, 543.2), score = 0.84
# the 62/68-th point : (676.8, 543.8), score = 0.73
# the 63/68-th point : (698.8, 544.5), score = 0.57
# the 64/68-th point : (736.0, 557.2), score = 0.69
# the 65/68-th point : (697.3, 560.7), score = 0.53
# the 66/68-th point : (676.3, 561.3), score = 0.68
# the 67/68-th point : (653.3, 558.5), score = 0.74
# save the visualization results into None
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (456.6, 315.7), score = 0.39
# the 01/68-th point : (448.4, 360.6), score = 0.70
# the 02/68-th point : (453.9, 423.3), score = 0.61
# the 03/68-th point : (465.6, 484.9), score = 0.47
# the 04/68-th point : (477.3, 556.8), score = 0.32
# the 05/68-th point : (499.4, 617.5), score = 0.41
# the 06/68-th point : (540.8, 660.4), score = 0.33
# the 07/68-th point : (609.8, 691.9), score = 0.16
# the 08/68-th point : (656.3, 691.4), score = 0.06
# the 09/68-th point : (716.3, 690.8), score = 0.16
# the 10/68-th point : (771.7, 672.7), score = 0.53
# the 11/68-th point : (810.0, 620.7), score = 0.50
# the 12/68-th point : (839.3, 565.3), score = 0.62
# the 13/68-th point : (858.0, 506.0), score = 0.64
# the 14/68-th point : (871.9, 445.5), score = 0.45
# the 15/68-th point : (880.0, 387.7), score = 0.83
# the 16/68-th point : (886.0, 335.7), score = 0.56
# the 17/68-th point : (483.8, 273.5), score = 0.58
# the 18/68-th point : (509.7, 255.4), score = 0.72
# the 19/68-th point : (550.5, 252.2), score = 0.58
# the 20/68-th point : (596.8, 262.0), score = 0.78
# the 21/68-th point : (638.3, 278.5), score = 0.56
# the 22/68-th point : (722.7, 283.1), score = 0.55
# the 23/68-th point : (760.3, 270.2), score = 0.42
# the 24/68-th point : (809.1, 267.3), score = 0.58
# the 25/68-th point : (852.2, 279.5), score = 0.64
# the 26/68-th point : (863.2, 303.3), score = 0.49
# the 27/68-th point : (678.7, 308.8), score = 0.71
# the 28/68-th point : (681.4, 345.7), score = 0.85
# the 29/68-th point : (681.0, 379.3), score = 0.55
# the 30/68-th point : (681.6, 419.6), score = 0.68
# the 31/68-th point : (621.4, 460.0), score = 0.71
# the 32/68-th point : (649.0, 469.6), score = 0.48
# the 33/68-th point : (676.4, 474.8), score = 0.66
# the 34/68-th point : (703.0, 468.8), score = 0.49
# the 35/68-th point : (727.0, 461.9), score = 0.47
# the 36/68-th point : (524.3, 303.6), score = 0.74
# the 37/68-th point : (549.7, 294.4), score = 0.56
# the 38/68-th point : (586.6, 293.3), score = 0.39
# the 39/68-th point : (611.4, 305.8), score = 0.46
# the 40/68-th point : (586.0, 307.0), score = 0.52
# the 41/68-th point : (553.6, 307.1), score = 0.61
# the 42/68-th point : (728.9, 314.0), score = 0.41
# the 43/68-th point : (764.3, 305.9), score = 0.74
# the 44/68-th point : (796.9, 310.7), score = 0.73
# the 45/68-th point : (823.7, 319.9), score = 0.78
# the 46/68-th point : (796.3, 322.6), score = 0.82
# the 47/68-th point : (760.7, 318.3), score = 0.66
# the 48/68-th point : (595.6, 561.9), score = 0.72
# the 49/68-th point : (624.2, 539.1), score = 0.75
# the 50/68-th point : (655.6, 528.2), score = 0.74
# the 51/68-th point : (676.6, 532.6), score = 0.46
# the 52/68-th point : (698.0, 529.8), score = 0.49
# the 53/68-th point : (730.0, 540.7), score = 0.68
# the 54/68-th point : (754.3, 564.8), score = 0.57
# the 55/68-th point : (726.3, 591.0), score = 0.50
# the 56/68-th point : (697.6, 601.4), score = 0.47
# the 57/68-th point : (673.2, 601.6), score = 0.56
# the 58/68-th point : (647.7, 598.7), score = 0.59
# the 59/68-th point : (620.7, 586.4), score = 0.73
# the 60/68-th point : (617.4, 561.4), score = 0.51
# the 61/68-th point : (653.8, 549.2), score = 0.73
# the 62/68-th point : (676.0, 550.8), score = 0.61
# the 63/68-th point : (697.9, 550.1), score = 0.51
# the 64/68-th point : (736.0, 562.8), score = 0.75
# the 65/68-th point : (695.6, 566.0), score = 0.49
# the 66/68-th point : (676.2, 567.9), score = 0.62
# the 67/68-th point : (653.0, 564.2), score = 0.81
# save the visualization results into None
# IN-shape : [1, 3, 256, 256], FLOPs : 27549.318144 MB, Params : 16.716687 MB
# the coordinates for 68 facial landmarks:
# the 00/68-th point : (457.6, 314.6), score = 0.41
# the 01/68-th point : (449.6, 359.2), score = 0.68
# the 02/68-th point : (454.7, 422.4), score = 0.61
# the 03/68-th point : (466.5, 482.5), score = 0.50
# the 04/68-th point : (477.5, 554.6), score = 0.38
# the 05/68-th point : (499.0, 614.6), score = 0.43
# the 06/68-th point : (541.4, 661.3), score = 0.30
# the 07/68-th point : (609.0, 691.2), score = 0.26
# the 08/68-th point : (660.8, 692.0), score = 0.12
# the 09/68-th point : (718.0, 691.0), score = 0.25
# the 10/68-th point : (771.8, 669.7), score = 0.56
# the 11/68-th point : (810.4, 617.9), score = 0.44
# the 12/68-th point : (839.9, 563.1), score = 0.62
# the 13/68-th point : (858.2, 503.2), score = 0.73
# the 14/68-th point : (872.1, 443.0), score = 0.37
# the 15/68-th point : (881.0, 384.8), score = 0.83
# the 16/68-th point : (886.1, 332.8), score = 0.71
# the 17/68-th point : (483.7, 270.3), score = 0.50
# the 18/68-th point : (509.1, 252.1), score = 0.62
# the 19/68-th point : (549.5, 249.4), score = 0.51
# the 20/68-th point : (594.4, 259.8), score = 0.75
# the 21/68-th point : (636.4, 275.4), score = 0.52
# the 22/68-th point : (721.8, 279.4), score = 0.52
# the 23/68-th point : (758.0, 264.2), score = 0.53
# the 24/68-th point : (808.2, 262.1), score = 0.70
# the 25/68-th point : (849.9, 273.1), score = 0.46
# the 26/68-th point : (861.5, 296.2), score = 0.49
# the 27/68-th point : (677.5, 305.2), score = 0.72
# the 28/68-th point : (679.7, 342.6), score = 0.75
# the 29/68-th point : (679.8, 377.1), score = 0.57
# the 30/68-th point : (680.7, 416.0), score = 0.76
# the 31/68-th point : (621.4, 457.4), score = 0.74
# the 32/68-th point : (648.0, 467.3), score = 0.47
# the 33/68-th point : (675.1, 471.6), score = 0.56
# the 34/68-th point : (702.3, 466.6), score = 0.45
# the 35/68-th point : (726.0, 459.0), score = 0.50
# the 36/68-th point : (524.7, 301.5), score = 0.73
# the 37/68-th point : (549.1, 291.1), score = 0.47
# the 38/68-th point : (581.6, 291.8), score = 0.40
# the 39/68-th point : (614.4, 302.5), score = 0.47
# the 40/68-th point : (585.2, 304.9), score = 0.55
# the 41/68-th point : (552.8, 305.4), score = 0.66
# the 42/68-th point : (727.7, 311.8), score = 0.49
# the 43/68-th point : (761.7, 301.3), score = 0.68
# the 44/68-th point : (795.4, 306.5), score = 0.79
# the 45/68-th point : (821.5, 316.8), score = 0.70
# the 46/68-th point : (794.9, 319.1), score = 0.72
# the 47/68-th point : (759.5, 315.3), score = 0.51
# the 48/68-th point : (595.7, 559.8), score = 0.69
# the 49/68-th point : (623.8, 537.1), score = 0.67
# the 50/68-th point : (655.4, 525.9), score = 0.78
# the 51/68-th point : (675.6, 532.5), score = 0.50
# the 52/68-th point : (697.5, 527.3), score = 0.52
# the 53/68-th point : (729.3, 538.7), score = 0.61
# the 54/68-th point : (753.0, 562.9), score = 0.61
# the 55/68-th point : (726.0, 588.1), score = 0.55
# the 56/68-th point : (697.6, 597.6), score = 0.39
# the 57/68-th point : (672.8, 598.3), score = 0.49
# the 58/68-th point : (647.3, 595.0), score = 0.47
# the 59/68-th point : (619.8, 583.9), score = 0.72
# the 60/68-th point : (616.5, 559.2), score = 0.48
# the 61/68-th point : (653.6, 546.5), score = 0.79
# the 62/68-th point : (675.8, 548.1), score = 0.66
# the 63/68-th point : (697.6, 547.6), score = 0.53
# the 64/68-th point : (735.4, 560.5), score = 0.74
# the 65/68-th point : (699.2, 564.3), score = 0.51
# the 66/68-th point : (674.9, 564.7), score = 0.64
# the 67/68-th point : (652.6, 561.5), score = 0.79
# save the visualization results into None

# %% [markdown]
# #### visualize result

# %%
# path = [f"../result/test_data/{i}" for i in os.listdir("./pngs")]
paths = [ Image.open(i) for i in glob.glob('./result/test_data/*.png')]
imageio.mimsave('./test.gif', paths, fps=5)

# %% [markdown]
# ![test](https://user-images.githubusercontent.com/97432613/160321764-c3979852-21ab-4fec-a341-9d2ce14a602a.gif)

# %% [markdown]
# # 4. Evaluate
